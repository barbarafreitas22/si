# %% [markdown]
# # Exercise 3: Test the SelectPercentile class
#
# ## SIB - Intelligent Systems for Bioinformatics
#
# Bárbara Freitas PG55693

# %%
import numpy as np
from si.io.csv_file import read_csv
from si.feature_selection.select_percentile import SelectPercentile

# --- 1. Load the Dataset ---
# Adjust the path if your notebook is in a different folder.
# Assuming running from 'scripts/' and dataset is in 'datasets/iris/'


iris_dataset = read_csv('../datasets/iris/iris.csv', features=True, label=True)

print("Original Dataset Shape:", iris_dataset.shape())
print("Original Features:", iris_dataset.features)

# --- 2. Initialize SelectPercentile ---
# We want to retain the top 50% of features.
# Since the Iris dataset has 4 features, we expect 2 features to be selected.
selector = SelectPercentile(percentile=50)

# --- 3. Fit the selector to the data ---
# This computes the F-scores and p-values for each feature.
selector.fit(iris_dataset)

print("\nComputed F-scores per feature:")
for feat, score in zip(iris_dataset.features, selector.F):
    print(f"  - {feat}: {score:.4f}")

# --- 4. Transform the dataset ---
# This filters the dataset, keeping only the selected features.
iris_selected = selector.transform(iris_dataset)

print("\n--- Selection Result ---")
print("New Dataset Shape:", iris_selected.shape())
print("Selected Features:", iris_selected.features)

# Verification:
# In the Iris dataset, 'petal_length' and 'petal_width' are typically the most 
# discriminative features and should be the ones selected by the F-test.
# Out:
# Original Dataset Shape: (150, 4)
# Original Features: Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width'], dtype='object')
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 18
#      13 print("Original Features:", iris_dataset.features)
#      15 # --- 2. Initialize SelectPercentile ---
#      16 # We want to retain the top 50% of features.
#      17 # Since the Iris dataset has 4 features, we expect 2 features to be selected.
# ---> 18 selector = SelectPercentile(percentile=50)
#      20 # --- 3. Fit the selector to the data ---
#      21 # This computes the F-scores and p-values for each feature.
#      22 selector.fit(iris_dataset)
#
# File ~/Documents/GitHub/si/src/si/feature_selection/select_percentile.py:29, in SelectPercentile.__init__(self, score_func, percentile)
#      15 """
# ...
